# %%
import carla

client = carla.Client("localhost", 2000)
client.set_timeout(10.0)

world = client.get_world()
print("Connected to world:", world.get_map().name)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4648\2897251694.py in <module>
#       4 client.set_timeout(10.0)
#       5
# ----> 6 world = client.get_world()
#       7 print("Connected to world:", world.get_map().name)
#
# RuntimeError: time-out of 10000ms while waiting for the simulator, make sure the simulator is ready and connected to localhost:2000
